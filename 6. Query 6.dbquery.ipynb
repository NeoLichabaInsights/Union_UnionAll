-- %%
SELECT
  *
FROM
  union_unionall.banking.atm_01_transactions;

SELECT
  *
FROM
  union_unionall.banking.atm_02_transactions;

-- Create a complete log of all ATM transactions
SELECT
  txn_id AS transaction_id,
  account_id,
  amount,
  NULL as transaction_date
FROM
  union_unionall.banking.atm_01_transactions
UNION ALL
SELECT
  txn_id AS transaction_id,
  account_id,
  amount,
  NULL as transaction_date
FROM
  union_unionall.banking.atm_02_transactions;
