-- %%
SELECT *
FROM union_unionall.banking.credit_entries;

SELECT * 
FROM union_unionall.banking.debit_entries;

-- All accounting entries to be on one general ledger for the audit.

SELECT entry_id, account_id, entry_type,
NULL as amount,
NULL as entry_date
FROM union_unionall.banking.credit_entries
UNION ALL

SELECT entry_id, account_id, entry_type,
NULL as amount,
NULL as entry_date
FROM union_unionall.banking.debit_entries;
